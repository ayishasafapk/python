# %%
print("hello")
# Out:
# hello

# %%
name="ayisha"
print("name:" +name)
# Out:
# name:ayisha

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
sum=int(input("enter value"))
add=int(input("enter value"))
print(sum)
print(add)
c=(sum + add)
print(c)
# Out:
# enter value10
# enter value20
# 10
# 20
# 30

# %%
age=22
mark=70.5
name="ayisha"
name=input("enter name:")
age=int(input("enter age:"))
mark=float(input("enter mark:"))
print(type(name))
print(type(age))
print(type(mark))
# Out:
# enter name:Ayisha
# enter age:23
# enter mark:30.5
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name=input("enter name:")
qualification=input("qualification:")
print(name)
print(qualification)
# Out:
# enter name:Ayisha safa pk
# qualification:mca
# Ayisha safa pk
# mca
